# %% [markdown]
# # Scatter Plots and Adding Colorbars

# %%
import numpy as np
import matplotlib; matplotlib.use('nbagg') # a notebook backend
import matplotlib.pyplot as plt
plt.ion() # plots will update automatically

# %% [markdown]
# Use `np.genfromtxt` to load `"sample_data.txt"`, which contains measurements for the distribution of flowers in a field.

# %%
x, dx, y, dy, count = np.genfromtxt("sample_data.txt", skip_header=2,
                                    delimiter=',', unpack=True)

# %% [markdown]
# A simple scatter plot shows the distribution of (x,y) points.

# %%
fig, ax = plt.subplots()
ax.scatter(x,y)
ax.set_xlabel('x (m)')
ax.set_ylabel('y (m)')
# to save our figure:
fig.savefig('scatter.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Conveying Magnitude

# %% [markdown]
# Our data contains more than just x and y. We also have information about the number of flowers at each point. There are two ways we can convey this information through our scatter plot: size and color.

# %% [markdown]
# ## Size

# %% [markdown]
# We can use the size of the scatter plot markers to indicate the relative number of flowers at each location by passing `count` to the `s` argument

# %%
fig, ax = plt.subplots()
ax.scatter(x,y,s=count)
ax.set_xlabel('x (m)')
ax.set_ylabel('y (m)')
fig.savefig('scatter_size.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'y (m)')

# %% [markdown]
# ## Color

# %% [markdown]
# To color the scatter plot markers based on the number of flowers at that point, we must pass `count` to the `c` arguemnt.
#
# If we're going to use color to convey information, we had better include a color bar. To create a color bar, we must save the plot object returned by `scatter` to a variable, so that the color bar knows what to scale to.

# %%
fig, ax = plt.subplots()
p = ax.scatter(x,y,c=count)
fig.colorbar(p)
ax.set_xlabel('x (m)')
ax.set_ylabel('y (m)')
fig.savefig('scatter_color.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'y (m)')
